# %%
# !pip install pytubefix
# Out:
# Requirement already satisfied: pytubefix in /home/torfinhell/miniconda3/envs/for_notebooks/lib/python3.13/site-packages (10.3.6)
# Requirement already satisfied: aiohttp>=3.12.13 in /home/torfinhell/miniconda3/envs/for_notebooks/lib/python3.13/site-packages (from pytubefix) (3.13.2)
# Requirement already satisfied: nodejs-wheel-binaries>=22.20.0 in /home/torfinhell/miniconda3/envs/for_notebooks/lib/python3.13/site-packages (from pytubefix) (24.12.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/torfinhell/miniconda3/envs/for_notebooks/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/torfinhell/miniconda3/envs/for_notebooks/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/torfinhell/miniconda3/envs/for_notebooks/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/torfinhell/miniconda3/envs/for_notebooks/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/torfinhell/miniconda3/envs/for_notebooks/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/torfinhell/miniconda3/envs/for_notebooks/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/torfinhell/miniconda3/envs/for_notebooks/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /home/torfinhell/miniconda3/envs/for_notebooks/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.12.13->pytubefix) (3.11)

# %%
from pytubefix import Playlist
import os
from pathlib import Path
save_path="output_videos"
url = "https://www.youtube.com/playlist?list=RDCLAK5uy_lE5hd-xT1yLqpoQWn8BOo99JL45hC31d8&playnext=1&index=1"

pl = Playlist(url)
for video in pl.videos:
    try:
        stream = video.streams.get_highest_resolution()
        filename = stream.default_filename
        full_path = os.path.join(save_path, filename)
        if os.path.exists(full_path):
            print(f"Skipping (already exists): {filename}")
            continue
        print(f"Downloading: {filename}")
        stream.download(save_path)
    except Exception as e:
        print(f"Error downloading video video: {video.title} with exception: {e}")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/urllib/request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/http/client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/http/client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# -> 1384 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/http/client.py:1333, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1332     raise CannotSendHeader()
# -> 1333 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/http/client.py:1093, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1092 del self._buffer[:]
# -> 1093 self.send(msg)
#    1095 if message_body is not None:
#    1096
#    1097     # create a consistent interface to message_body
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/http/client.py:1037, in HTTPConnection.send(self, data)
#    1036 if self.auto_open:
# -> 1037     self.connect()
#    1038 else:
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/http/client.py:1479, in HTTPSConnection.connect(self)
#    1477     server_hostname = self.host
# -> 1479 self.sock = self._context.wrap_socket(self.sock,
#    1480                                       server_hostname=server_hostname)
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/ssl.py:1076, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1075                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1076             self.do_handshake()
#    1077 except:
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/ssl.py:1372, in SSLSocket.do_handshake(self, block)
#    1371         self.settimeout(None)
# -> 1372     self._sslobj.do_handshake()
#    1373 finally:
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[2], line 8
#       5 url = "https://www.youtube.com/playlist?list=RDCLAK5uy_lE5hd-xT1yLqpoQWn8BOo99JL45hC31d8&playnext=1&index=1"
#       7 pl = Playlist(url)
# ----> 8 for video in pl.videos:
#       9     try:
#      10         stream = video.streams.get_highest_resolution()
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/site-packages/pytubefix/helpers.py:73, in DeferredGeneratorList.__iter__(self)
#      71 while True:
#      72     try:
# ---> 73         curr_item = self[iter_index]
#      74     except IndexError:
#      75         return
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/site-packages/pytubefix/helpers.py:59, in DeferredGeneratorList.__getitem__(self, key)
#      57 while len(self._elements) < key_slice.stop:
#      58     try:
# ---> 59         next_item = next(self.gen)
#      60     except StopIteration:
#      61         # If we can't find enough elements for the slice, raise an IndexError
#      62         raise IndexError
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/site-packages/pytubefix/contrib/playlist.py:344, in Playlist.videos_generator(self)
#     343 def videos_generator(self):
# --> 344     for url in self.video_urls:
#     345         yield YouTube(
#     346             url,
#     347             client=self.client,
#    (...)    353             po_token_verifier=self.po_token_verifier
#     354         )
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/site-packages/pytubefix/helpers.py:73, in DeferredGeneratorList.__iter__(self)
#      71 while True:
#      72     try:
# ---> 73         curr_item = self[iter_index]
#      74     except IndexError:
#      75         return
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/site-packages/pytubefix/helpers.py:59, in DeferredGeneratorList.__getitem__(self, key)
#      57 while len(self._elements) < key_slice.stop:
#      58     try:
# ---> 59         next_item = next(self.gen)
#      60     except StopIteration:
#      61         # If we can't find enough elements for the slice, raise an IndexError
#      62         raise IndexError
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/site-packages/pytubefix/contrib/playlist.py:329, in Playlist.url_generator(self)
#     324 def url_generator(self):
#     325     """Generator that yields video URLs.
#     326
#     327     :Yields: Video URLs
#     328     """
# --> 329     for page in self._paginate(self.html):
#     330         for video in page:
#     331             yield self._video_url(video)
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/site-packages/pytubefix/contrib/playlist.py:106, in Playlist.html(self)
#     104 if self._html:
#     105     return self._html
# --> 106 self._html = request.get(self.playlist_url)
#     107 return self._html
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/site-packages/pytubefix/request.py:51, in get(url, extra_headers, timeout)
#      49 if extra_headers is None:
#      50     extra_headers = {}
# ---> 51 response = _execute_request(url, headers=extra_headers, timeout=timeout)
#      52 return response.read().decode("utf-8")
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/site-packages/pytubefix/request.py:35, in _execute_request(url, method, headers, data, timeout)
#      33 else:
#      34     raise ValueError("Invalid URL")
# ---> 35 return urlopen(request, timeout=timeout)
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/urllib/request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/urllib/request.py:489, in OpenerDirector.open(self, fullurl, data, timeout)
#     486     req = meth(req)
#     488 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 489 response = self._open(req, data)
#     491 # post-process response
#     492 meth_name = protocol+"_response"
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/urllib/request.py:506, in OpenerDirector._open(self, req, data)
#     503     return result
#     505 protocol = req.type
# --> 506 result = self._call_chain(self.handle_open, protocol, protocol +
#     507                           '_open', req)
#     508 if result:
#     509     return result
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/urllib/request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/urllib/request.py:1367, in HTTPSHandler.https_open(self, req)
#    1366 def https_open(self, req):
# -> 1367     return self.do_open(http.client.HTTPSConnection, req,
#    1368                         context=self._context)
#
# File ~/miniconda3/envs/for_notebooks/lib/python3.13/urllib/request.py:1322, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1319         h.request(req.get_method(), req.selector, req.data, headers,
#    1320                   encode_chunked=req.has_header('Transfer-encoding'))
#    1321     except OSError as err: # timeout error
# -> 1322         raise URLError(err)
#    1323     r = h.getresponse()
#    1324 except:
#
# URLError: <urlopen error [Errno 110] Connection timed out>
