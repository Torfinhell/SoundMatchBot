# %%
# !pip install pytubefix
# Out:
# Collecting pytubefix
#   Downloading pytubefix-10.3.8-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: aiohttp>=3.12.13 in /usr/local/lib/python3.12/dist-packages (from pytubefix) (3.13.3)
# Collecting nodejs-wheel-binaries>=22.20.0 (from pytubefix)
#   Downloading nodejs_wheel_binaries-24.14.0-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.12.13->pytubefix) (1.23.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp>=3.12.13->pytubefix) (4.15.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.12.13->pytubefix) (3.11)
# Downloading pytubefix-10.3.8-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 17.2 MB/s eta 0:00:00
# Downloading nodejs_wheel_binaries-24.14.0-py2.py3-none-manylinux_2_28_x86_64.whl (59.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 MB 17.2 MB/s eta 0:00:00
# Installing collected packages: nodejs-wheel-binaries, pytubefix
# Successfully installed nodejs-wheel-binaries-24.14.0 pytubefix-10.3.8

# %%
from pytubefix import Playlist
import os
from pathlib import Path
save_path="output_videos"
url = "https://www.youtube.com/playlist?list=RDCLAK5uy_lE5hd-xT1yLqpoQWn8BOo99JL45hC31d8&playnext=1&index=1"

pl = Playlist(url)
for video in pl.videos:
    try:
        stream = video.streams.get_highest_resolution()
        filename = stream.default_filename
        full_path = os.path.join(save_path, filename)
        if os.path.exists(full_path):
            print(f"Skipping (already exists): {filename}")
            continue
        print(f"Downloading: {filename}")
        stream.download(save_path)
    except Exception as e:
        print(f"Error downloading video video: {video.title} with exception: {e}")
# Out:
# Downloading: Billie Eilish - WILDFLOWER (BILLIE BY FINNEAS).mp4
# Downloading: Lizzy McAlpine - ceilings (official video).mp4
# Downloading: Gracie Abrams - I miss you, I’m sorry (Lyric Video).mp4
# Downloading: Conan Gray - Heather.mp4
# Downloading: Gigi Perez - Sailor Song (Official Music Video).mp4
# Downloading: Taylor Swift - Fortnight (feat. Post Malone) (Official Music Video).mp4
# Downloading: Hozier - Too Sweet (Official Video).mp4
# Downloading: Mitski - My Love Mine All Mine (Official Video).mp4
# Downloading: yung kai - blue (official audio).mp4
# Downloading: Billie Eilish - BIRDS OF A FEATHER (Official Music Video).mp4
# Downloading: Gracie Abrams - That’s So True (Official Lyric Video).mp4
# Downloading: Taylor Swift - The Life of a Showgirl (Feat. Sabrina Carpenter) (Lyric Video).mp4
# Downloading: Harry Styles - Matilda (Audio).mp4
# Downloading: Powfu - death bed (coffee for your head) (Official Video) ft. beabadoobee.mp4
# Downloading: Bon Iver - Holocene - Official Video.mp4
# Downloading: Lana Del Rey - Say Yes To Heaven (Official Audio).mp4
# Downloading: Billie Eilish - What Was I Made For? (Official Music Video).mp4
# Downloading: Olivia Rodrigo - lacy (Official Lyric Video).mp4
# Downloading: girl in red - we fell in love in october.mp4
# Downloading: beabadoobee, Laufey - A Night To Remember (Official Music Video).mp4
